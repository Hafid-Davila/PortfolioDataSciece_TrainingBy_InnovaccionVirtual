# %% [markdown]
# # Prácticas de Computer Vision

# %%
# Establecemos nuestras cerdenciales

key = 'b23cd2f264ed4b1fb35c718b34029e4b'
endpoint = 'https://cv-drjrz-lab01.cognitiveservices.azure.com/'

# %%
# Conectamos con Azure

from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(key))

# %%
import vision
import os

# %matplotlib inline

# Obtenemos una imagen de nuestra elección
image_path = './Data/VisionComputacional/frederik-trovatten-com-8ikTPI-novk-unsplash.jpg'

image_stream = open(image_path, 'rb')
description = client.describe_image_in_stream(image_stream)

print(description)

vision.show_image_caption(image_path, description)
# Out:
# {'additional_properties': {}, 'tags': ['car', 'bus', 'transport', 'outdoor', 'van', 'vehicle'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x00000274818E8EB0>], 'request_id': '34a6f65b-b0d8-4772-be20-0abe629f24ad', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x00000274818E8FD0>, 'model_version': '2021-05-01'}

# %%
image_path = './Data/VisionComputacional/austin-distel-TluMvvrZ57g-unsplash.jpg'
image_stream = open(image_path, 'rb')
description = client.describe_image_in_stream(image_stream)

vision.show_image_caption(image_path, description)

# %%
# Obtenemos una imagen de nuestra elección
image_path = './Data/VisionComputacional/frederik-trovatten-com-8ikTPI-novk-unsplash.jpg'

features = ['Description', 'Tags', 'Adult', 'Objects', 'Faces']

image_stream = open(image_path, 'rb')
analysis = client.analyze_image_in_stream(image_stream, visual_features=features)

vision.show_image_analysis(image_path, analysis)

# %% [markdown]
# # Practicas de Face API

# %%
key = '816f13e2132943339be81a7cbb386662'
endpoint = 'https://face-drjrz-lab2.cognitiveservices.azure.com/'

# %%
# Conectamos con Azure

from azure.cognitiveservices.vision.face import FaceClient
from msrest.authentication import CognitiveServicesCredentials

client = FaceClient(endpoint, CognitiveServicesCredentials(key))

# %%
# preparamos el entorno

import faces 
import os 
# %matplotlib inline

# %%
# Obetenemos una imagen para detectar rostros

image_path = './Data/VisionComputacional/moise-m-HTP5klp7fn4-unsplash.jpg'
image_stream = open(image_path, 'rb')

detected_faces = client.face.detect_with_stream(image = image_stream)

faces.show_faces(image_path, detected_faces)

# %%
# Obetenemos una imagen para detectar rostros y su identificación

image_path = './Data/VisionComputacional/moise-m-HTP5klp7fn4-unsplash.jpg'
image_stream = open(image_path, 'rb')

detected_faces = client.face.detect_with_stream(image = image_stream)

faces.show_faces(image_path, detected_faces, show_id=True)

# %%
# Obetenemos una imagen para dectectar rostros y sus atributos

image_path = './data/visioncomputacional/frederik-trovatten-com-8ikTPI-novk-unsplash.jpg'
image_stream = open(image_path, 'rb')

attributes = ['age', 'emotion']
detected_faces = client.face.detect_with_stream(image = image_stream, return_face_attributes=attributes)

faces.show_face_attributes(image_path, detected_faces)
